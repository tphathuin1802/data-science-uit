# %%
from sklearn.datasets import fetch_openml
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %%
X, y = fetch_openml('mnist_784', version=1, return_X_y=True, as_frame=False)
# Split the dataset into training and testing sets

X_train, X_test = X[:60000], X[60000:]
y_train, y_test = y[:60000], y[60000:]
# Normalize the data

X_train = X_train / 255.0
X_test = X_test / 255.0
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 X, y = fetch_openml('mnist_784', version=1, return_X_y=True, as_frame=False)
#       2 # Split the dataset into training and testing sets
#       4 X_train, X_test = X[:60000], X[60000:]
#
# File c:\Users\phath\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File c:\Users\phath\anaconda3\Lib\site-packages\sklearn\datasets\_openml.py:1130, in fetch_openml(name, version, data_id, data_home, target_column, cache, return_X_y, as_frame, n_retries, delay, parser, read_csv_kwargs)
#    1128 # obtain the data
#    1129 url = _DATA_FILE.format(data_description["file_id"])
# -> 1130 bunch = _download_data_to_bunch(
#    1131     url,
#    1132     return_sparse,
#    1133     data_home,
#    1134     as_frame=bool(as_frame),
#    1135     openml_columns_info=features_list,
#    1136     shape=shape,
#    1137     target_columns=target_columns,
#    1138     data_columns=data_columns,
#    1139     md5_checksum=data_description["md5_checksum"],
#    1140     n_retries=n_retries,
#    1141     delay=delay,
#    1142     parser=parser_,
#    1143     read_csv_kwargs=read_csv_kwargs,
#    1144 )
#    1146 if return_X_y:
#    1147     return bunch.data, bunch.target
#
# File c:\Users\phath\anaconda3\Lib\site-packages\sklearn\datasets\_openml.py:684, in _download_data_to_bunch(url, sparse, data_home, as_frame, openml_columns_info, data_columns, target_columns, shape, md5_checksum, n_retries, delay, parser, read_csv_kwargs)
#     680     from pandas.errors import ParserError
#     682     no_retry_exception = ParserError
# --> 684 X, y, frame, categories = _retry_with_clean_cache(
#     685     url, data_home, no_retry_exception
#     686 )(_load_arff_response)(
#     687     url,
#     688     data_home,
#     689     parser=parser,
#     690     output_type=output_type,
#     691     openml_columns_info=features_dict,
#     692     feature_names_to_select=data_columns,
#     693     target_names_to_select=target_columns,
#     694     shape=shape,
#     695     md5_checksum=md5_checksum,
#     696     n_retries=n_retries,
#     697     delay=delay,
#     698     read_csv_kwargs=read_csv_kwargs,
#     699 )
#     701 return Bunch(
#     702     data=X,
#     703     target=y,
#    (...)    707     target_names=target_columns,
#     708 )
#
# File c:\Users\phath\anaconda3\Lib\site-packages\sklearn\datasets\_openml.py:67, in _retry_with_clean_cache.<locals>.decorator.<locals>.wrapper(*args, **kw)
#      65     return f(*args, **kw)
#      66 try:
# ---> 67     return f(*args, **kw)
#      68 except URLError:
#      69     raise
#
# File c:\Users\phath\anaconda3\Lib\site-packages\sklearn\datasets\_openml.py:519, in _load_arff_response(url, data_home, parser, output_type, openml_columns_info, feature_names_to_select, target_names_to_select, shape, md5_checksum, n_retries, delay, read_csv_kwargs)
#     436 def _load_arff_response(
#     437     url: str,
#     438     data_home: Optional[str],
#    (...)    448     read_csv_kwargs: Optional[Dict] = None,
#     449 ):
#     450     """Load the ARFF data associated with the OpenML URL.
#     451
#     452     In addition of loading the data, this function will also check the
#    (...)    517         `output_array_type == "pandas"`.
#     518     """
# --> 519     gzip_file = _open_openml_url(url, data_home, n_retries=n_retries, delay=delay)
#     520     with closing(gzip_file):
#     521         md5 = hashlib.md5()
#
# File c:\Users\phath\anaconda3\Lib\site-packages\sklearn\datasets\_openml.py:183, in _open_openml_url(openml_path, data_home, n_retries, delay)
#     181                 opener = gzip.GzipFile
#     182             with opener(os.path.join(tmpdir, file_name), "wb") as fdst:
# --> 183                 shutil.copyfileobj(fsrc, fdst)
#     184         shutil.move(fdst.name, local_path)
#     185 except Exception:
#
# File c:\Users\phath\anaconda3\Lib\shutil.py:203, in copyfileobj(fsrc, fdst, length)
#     201 fsrc_read = fsrc.read
#     202 fdst_write = fdst.write
# --> 203 while buf := fsrc_read(length):
#     204     fdst_write(buf)
#
# File c:\Users\phath\anaconda3\Lib\http\client.py:473, in HTTPResponse.read(self, amt)
#     470     return b""
#     472 if self.chunked:
# --> 473     return self._read_chunked(amt)
#     475 if amt is not None:
#     476     if self.length is not None and amt > self.length:
#     477         # clip the read to the "end of response"
#
# File c:\Users\phath\anaconda3\Lib\http\client.py:601, in HTTPResponse._read_chunked(self, amt)
#     598     self.chunk_left = chunk_left - amt
#     599     break
# --> 601 value.append(self._safe_read(chunk_left))
#     602 if amt is not None:
#     603     amt -= chunk_left
#
# File c:\Users\phath\anaconda3\Lib\http\client.py:640, in HTTPResponse._safe_read(self, amt)
#     633 def _safe_read(self, amt):
#     634     """Read the number of bytes requested.
#     635
#     636     This function should be used when <amt> bytes "should" be present for
#     637     reading. If the bytes are truly not available (due to EOF), then the
#     638     IncompleteRead exception can be used to detect the problem.
#     639     """
# --> 640     data = self.fp.read(amt)
#     641     if len(data) < amt:
#     642         raise IncompleteRead(data, amt-len(data))
#
# File c:\Users\phath\anaconda3\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File c:\Users\phath\anaconda3\Lib\ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\phath\anaconda3\Lib\ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:
